# %%
# Imports
import pandas as pd
import plotly.express as px
from prettytable import PrettyTable
import plotly.graph_objects as go
import numpy as np
import random
import csv
import os
import json

# %%
# Local on Windows 10 box
#WD = r"D:\BUSTEDS-MH"

# MAC OSX
WD = "/Users/user/Documents/BUSTEDS-MH"
BUSTEDS_DIR = os.path.join(WD, "analysis/13-datasets/BUSTEDS")
BUSTEDS_MH_DIR = os.path.join(WD, "analysis/13-datasets/BUSTEDS-MH")

BUSTEDS_OUTPUT_CSV = os.path.join(WD, "Processed_13Datasets_BUSTEDS.csv")
BUSTEDS_MH_OUTPUT_CSV = os.path.join(WD, "Processed_13Datasets_BUSTEDS-MH.csv")
OUTPUT_CSV = os.path.join(WD, "Table_Processed_13Datasets_BUSTEDS_vs_BUSTEDS-MH.csv")

# %%
def read_json(filename):
    print("# Reading:", filename)
    if os.stat(filename).st_size == 0: 
        return []
    #end if
    with open(filename, "r") as fh:
        json_data = json.load(fh)
    fh.close()
    return json_data
#end method


#define function to calculate cv
#cv = lambda x: np.std(x, ddof=1) / np.mean(x) * 100 
cv = lambda x: np.std(x) / np.mean(x)

# %%
BUSTEDS_DIR_FILES = [os.path.join(BUSTEDS_DIR, file.name) for file in os.scandir(BUSTEDS_DIR) if file.name.endswith(".json")]
BUSTEDS_MH_DIR_FILES = [os.path.join(BUSTEDS_MH_DIR, file.name) for file in os.scandir(BUSTEDS_MH_DIR) if file.name.endswith(".json")]

print("# Number of BUSTEDS results:", len(BUSTEDS_DIR_FILES))
print("# Number of BUSTEDS-MH results:", len(BUSTEDS_MH_DIR_FILES))
# Out:
# # Number of BUSTEDS results: 13
# # Number of BUSTEDS-MH results: 13

# %%
BUSTEDS_MH_DIR_FILES
# Out:
# ['/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/InfluenzaA.nex.BUSTEDS-MH.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/COXI.nex.BUSTEDS-MH.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/flavNS5.nex.BUSTEDS-MH.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/ENCenv.nex.BUSTEDS-MH.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/adh.nex.BUSTEDS-MH.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/HIVvif.nex.BUSTEDS-MH.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/camelid.nex.BUSTEDS-MH.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/lysozyme.nex.BUSTEDS-MH.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/HIV_RT.nex.BUSTEDS-MH.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/HepatitisD.nex.BUSTEDS-MH.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/bglobin.nex.BUSTEDS-MH.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/yokoyama.rh1.cds.mod.1-990.nex.BUSTEDS-MH.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/lysin.nex.BUSTEDS-MH.json']

# %%
BUSTEDS_DIR_FILES
# Out:
# ['/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/HIVvif.nex.BUSTEDS.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/lysozyme.nex.BUSTEDS.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/COXI.nex.BUSTEDS.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/flavNS5.nex.BUSTEDS.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/bglobin.nex.BUSTEDS.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/ENCenv.nex.BUSTEDS.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/yokoyama.rh1.cds.mod.1-990.nex.BUSTEDS.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/HIV_RT.nex.BUSTEDS.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/adh.nex.BUSTEDS.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/lysin.nex.BUSTEDS.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/HepatitisD.nex.BUSTEDS.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/InfluenzaA.nex.BUSTEDS.json',
#  '/Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/camelid.nex.BUSTEDS.json']

# %%
df_dict = {}

# Set up header
with open('13Datasets_ER_Sites.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',')
    spamwriter.writerow(['Datafile', 'Count BUSTEDS-MH Sites',
                         'BUSTEDS-MH Sites', 'Count', 
                         'BUSTEDS Sites', "Count Intersection Sites", "Intersection Sites",
                        "Count of BUSTEDS-MH Unique sites", "BUSTEDS-MH Unique sites",
                        "Count of BUSTEDS Unique sites", "BUSTEDS Unique sites"])
#end with

for item in BUSTEDS_MH_DIR_FILES:
    basename = os.path.basename(item).replace(".nex.BUSTEDS-MH.json", "")
    
    # Find BUSTEDS File
    BUSTEDS_File = os.path.join(BUSTEDS_DIR, basename + ".nex.BUSTEDS.json")
    
    # Read json
    json_data_BUSTEDS_MH = read_json(item)
    json_data_BUSTEDS = read_json(BUSTEDS_File)
    
    print("# Data loaded")
    df_dict[basename] = {"Sequences": json_data_BUSTEDS_MH["input"]["number of sequences"]}
    df_dict[basename].update({"Codons": json_data_BUSTEDS_MH["input"]["number of sites"]})
    df_dict[basename].update({"PValue_BUSTEDS-MH": json_data_BUSTEDS_MH["test results"]["p-value"]})

    A = json_data_BUSTEDS_MH["fits"]["Unconstrained model"]["Rate Distributions"]["Test"]["0"]["omega"] 
    B = json_data_BUSTEDS_MH["fits"]["Unconstrained model"]["Rate Distributions"]["Test"]["1"]["omega"] 
    C = json_data_BUSTEDS_MH["fits"]["Unconstrained model"]["Rate Distributions"]["Test"]["2"]["omega"] 
    
    df_dict[basename].update({"CV(omega)_BUSTEDS-MH": cv([A, B, C])})
    
    D = json_data_BUSTEDS["fits"]["Unconstrained model"]["Rate Distributions"]["Synonymous site-to-site rates"]["0"]["rate"] 
    E = json_data_BUSTEDS["fits"]["Unconstrained model"]["Rate Distributions"]["Synonymous site-to-site rates"]["1"]["rate"] 
    F = json_data_BUSTEDS["fits"]["Unconstrained model"]["Rate Distributions"]["Synonymous site-to-site rates"]["2"]["rate"] 
  
    df_dict[basename].update({"CV(alpha)_BUSTEDS-MH": cv([D, E, F])})
    
    df_dict[basename].update({"omega_3_BUSTEDS-MH": json_data_BUSTEDS_MH["fits"]["Unconstrained model"]
                              ["Rate Distributions"]["Test"]["2"]["omega"]})
    df_dict[basename].update({"proportion_3_BUSTEDS-MH": json_data_BUSTEDS_MH["fits"]["Unconstrained model"]
                              ["Rate Distributions"]["Test"]["2"]["proportion"]})
    
    # DH rate, TH rate
    df_dict[basename].update({"DH_Rate": json_data_BUSTEDS_MH["fits"]["Unconstrained model"]
                              ["rate at which 2 nucleotides are changed instantly within a single codon"]})
    df_dict[basename].update({"TH_Rate": json_data_BUSTEDS_MH["fits"]["Unconstrained model"]
                              ["rate at which 3 nucleotides are changed instantly within a single codon"]})
    df_dict[basename].update({"TH_Rate_SI": json_data_BUSTEDS_MH["fits"]["Unconstrained model"]
                              ["rate at which 3 nucleotides are changed instantly within a single codon between synonymous codon islands"]})
    
    # BUSTEDS
    df_dict[basename].update({"PValue_BUSTEDS": json_data_BUSTEDS["test results"]["p-value"]})
    
    A = json_data_BUSTEDS["fits"]["Unconstrained model"]["Rate Distributions"]["Test"]["0"]["omega"] 
    B = json_data_BUSTEDS["fits"]["Unconstrained model"]["Rate Distributions"]["Test"]["1"]["omega"] 
    C = json_data_BUSTEDS["fits"]["Unconstrained model"]["Rate Distributions"]["Test"]["2"]["omega"] 
    
    df_dict[basename].update({"CV(omega)_BUSTEDS": cv([A, B, C])})
    
    D = json_data_BUSTEDS["fits"]["Unconstrained model"]["Rate Distributions"]["Synonymous site-to-site rates"]["0"]["rate"] 
    E = json_data_BUSTEDS["fits"]["Unconstrained model"]["Rate Distributions"]["Synonymous site-to-site rates"]["1"]["rate"] 
    F = json_data_BUSTEDS["fits"]["Unconstrained model"]["Rate Distributions"]["Synonymous site-to-site rates"]["2"]["rate"] 
    
    df_dict[basename].update({"CV(alpha)_BUSTEDS": cv([D, E, F])})
    df_dict[basename].update({"omega_3_BUSTEDS": json_data_BUSTEDS["fits"]["Unconstrained model"]
                              ["Rate Distributions"]["Test"]["2"]["omega"]})
    df_dict[basename].update({"proportion_3_BUSTEDS": json_data_BUSTEDS["fits"]["Unconstrained model"]
                              ["Rate Distributions"]["Test"]["2"]["proportion"]})
    
    # cAIC
    AICc_BUSTEDS_MH = json_data_BUSTEDS_MH["fits"]["Unconstrained model"]["AIC-c"]
    AICc_BUSTEDS = json_data_BUSTEDS["fits"]["Unconstrained model"]["AIC-c"]
    print("# Calculating 'Unconstrained model' AICc delta, (BUSTEDS-MH)", AICc_BUSTEDS_MH, "and (BUSTEDS)", AICc_BUSTEDS)
    delta_AICc = AICc_BUSTEDS_MH - AICc_BUSTEDS
    df_dict[basename].update({"delta_cAIC": delta_AICc})
    
    # ER Sites > 5
    ER_SITES_BUSTEDS = []
    ER_SITES_BUSTEDS_MH = []
    ER_Threshold = 5
    
    ER_df_dict = {}
    
    if "constrained" in json_data_BUSTEDS_MH["Evidence Ratios"].keys():
        print("# ER Constrained:", len(json_data_BUSTEDS_MH["Evidence Ratios"]["constrained"][0]))
        for site, val in enumerate(json_data_BUSTEDS_MH["Evidence Ratios"]["constrained"][0]):
            if val > ER_Threshold:
                ER_SITES_BUSTEDS_MH.append(str(site + 1))
                ER_df_dict[site + 1] = {"BUSTEDS-MH ER": val}
            #end if
        #end for
    #end if
    
    if "constrained" in json_data_BUSTEDS["Evidence Ratios"].keys():
        print("# ER Constrained:", len(json_data_BUSTEDS["Evidence Ratios"]["constrained"][0]))
        for site, val in enumerate(json_data_BUSTEDS["Evidence Ratios"]["constrained"][0]):
            if val > ER_Threshold:
                ER_SITES_BUSTEDS.append(str(site + 1))
                if site + 1 in ER_df_dict.keys():
                    ER_df_dict[site + 1].update({"BUSTEDS ER": val})
                else:
                    ER_df_dict[site + 1] = {"BUSTEDS-MH ER": val}
            #end if
        #end for
    #end if
    
    
    # This needs to be in a separate file
    print("# All BUSTEDS-MH ER Sites:",ER_SITES_BUSTEDS_MH, len(ER_SITES_BUSTEDS_MH))
    print("# All BUSTEDS ER Sites:", ER_SITES_BUSTEDS, len(ER_SITES_BUSTEDS))
    
    #union_of_sites = matches = [item for item in ER_SITES_BUSTEDS_MH if item in ER_SITES_BUSTEDS]
    #print(union_of_sites, len(union_of_sites))
    
    intersection = set(ER_SITES_BUSTEDS_MH).intersection(ER_SITES_BUSTEDS)
    print("# Intersection (where they both agree):", intersection, len(intersection))
    
    unique_to_BUSTEDS_MH = [str(x) for x in ER_SITES_BUSTEDS_MH if x not in ER_SITES_BUSTEDS]
    unique_to_BUSTEDS = [str(x) for x in ER_SITES_BUSTEDS if x not in ER_SITES_BUSTEDS_MH]
    
    print(unique_to_BUSTEDS_MH, len(unique_to_BUSTEDS_MH))
    print(unique_to_BUSTEDS, len(unique_to_BUSTEDS))
    
    with open('13Datasets_ER_Sites.csv', 'a', newline='') as csvfile:
        spamwriter = csv.writer(csvfile, delimiter=',')
        
        spamwriter.writerow([basename, str(len(ER_SITES_BUSTEDS_MH)), "|".join(ER_SITES_BUSTEDS_MH), 
                                       str(len(ER_SITES_BUSTEDS)), "|".join(ER_SITES_BUSTEDS),
                                       str(len(intersection)), str("|".join(intersection)),
                                       str(len(unique_to_BUSTEDS_MH)), "|".join(unique_to_BUSTEDS_MH),
                                       str(len(unique_to_BUSTEDS)), "|".join(unique_to_BUSTEDS)])
        
        
    #end with
    
    
    # Update dict
    
    # In BUSTEDS-MH and BUSTEDS
    df_dict[basename].update({"++": len(intersection)})
    
    # In BUSTEDS-MH and NOT BUSTEDS
    #df_dict[basename].update({"+-": abs(len(ER_SITES_BUSTEDS_MH) - len(intersection))})
    df_dict[basename].update({"+-": len(unique_to_BUSTEDS_MH)})
    #df_dict[basename].update({"+-": len(ER_SITES_BUSTEDS_MH)})
    
    # NOT in BUSTEDS-MH but in BUSTEDS
    #df_dict[basename].update({"-+": abs(len(ER_SITES_BUSTEDS) - len(intersection))})
    df_dict[basename].update({"-+": len(unique_to_BUSTEDS)})
    #df_dict[basename].update({"-+": len(ER_SITES_BUSTEDS)})
    
    print()
# Out:
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/InfluenzaA.nex.BUSTEDS-MH.json
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/InfluenzaA.nex.BUSTEDS.json
# # Data loaded
# # Calculating 'Unconstrained model' AICc delta, (BUSTEDS-MH) 23230.10669984552 and (BUSTEDS) 23242.49538542873
# # ER Constrained: 329
# # All BUSTEDS-MH ER Sites: [] 0
# # All BUSTEDS ER Sites: ['50', '80', '121', '128', '133', '135', '137', '138', '142', '145', '156', '157', '159', '163', '172', '182', '186', '190', '193', '194', '196', '198', '201', '214', '219', '226', '229', '275', '276', '310', '312'] 31
# # Intersection (where they both agree): set() 0
# [] 0
# ['50', '80', '121', '128', '133', '135', '137', '138', '142', '145', '156', '157', '159', '163', '172', '182', '186', '190', '193', '194', '196', '198', '201', '214', '219', '226', '229', '275', '276', '310', '312'] 31
#
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/COXI.nex.BUSTEDS-MH.json
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/COXI.nex.BUSTEDS.json
# # Data loaded
# # Calculating 'Unconstrained model' AICc delta, (BUSTEDS-MH) 24295.52533688448 and (BUSTEDS) 24288.71170588409
# # ER Constrained: 510
# # All BUSTEDS-MH ER Sites: [] 0
# # All BUSTEDS ER Sites: [] 0
# # Intersection (where they both agree): set() 0
# [] 0
# [] 0
#
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/flavNS5.nex.BUSTEDS-MH.json
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/flavNS5.nex.BUSTEDS.json
# # Data loaded
# # Calculating 'Unconstrained model' AICc delta, (BUSTEDS-MH) 18488.62691221152 and (BUSTEDS) 18530.58019870966
# # ER Constrained: 342
# # All BUSTEDS-MH ER Sites: [] 0
# # All BUSTEDS ER Sites: [] 0
# # Intersection (where they both agree): set() 0
# [] 0
# [] 0
#
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/ENCenv.nex.BUSTEDS-MH.json
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/ENCenv.nex.BUSTEDS.json
# # Data loaded
# # Calculating 'Unconstrained model' AICc delta, (BUSTEDS-MH) 13705.10984981396 and (BUSTEDS) 13699.07848237643
# # All BUSTEDS-MH ER Sites: [] 0
# # All BUSTEDS ER Sites: [] 0
# # Intersection (where they both agree): set() 0
# [] 0
# [] 0
#
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/adh.nex.BUSTEDS-MH.json
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/adh.nex.BUSTEDS.json
# # Data loaded
# # Calculating 'Unconstrained model' AICc delta, (BUSTEDS-MH) 9359.172806510542 and (BUSTEDS) 9353.863170589633
# # ER Constrained: 254
# # ER Constrained: 254
# # All BUSTEDS-MH ER Sites: ['6', '35', '39', '49', '69', '133', '134', '163', '165', '166', '170', '197', '216', '227', '253'] 15
# # All BUSTEDS ER Sites: ['4', '6', '35', '39', '46', '49', '69', '133', '134', '163', '165', '166', '170', '187', '197', '216', '227', '253'] 18
# # Intersection (where they both agree): {'134', '165', '216', '166', '163', '253', '197', '35', '49', '6', '69', '39', '227', '133', '170'} 15
# [] 0
# ['4', '46', '187'] 3
#
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/HIVvif.nex.BUSTEDS-MH.json
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/HIVvif.nex.BUSTEDS.json
# # Data loaded
# # Calculating 'Unconstrained model' AICc delta, (BUSTEDS-MH) 6911.008312547014 and (BUSTEDS) 6911.64906988795
# # ER Constrained: 192
# # All BUSTEDS-MH ER Sites: [] 0
# # All BUSTEDS ER Sites: ['6'] 1
# # Intersection (where they both agree): set() 0
# [] 0
# ['6'] 1
#
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/camelid.nex.BUSTEDS-MH.json
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/camelid.nex.BUSTEDS.json
# # Data loaded
# # Calculating 'Unconstrained model' AICc delta, (BUSTEDS-MH) 33668.36327010485 and (BUSTEDS) 33694.60454183659
# # ER Constrained: 96
# # ER Constrained: 96
# # All BUSTEDS-MH ER Sites: ['1', '11', '14', '23', '25', '29', '32', '33', '40', '50', '51', '52', '53', '54', '57', '58', '59', '72', '77', '78', '80', '93'] 22
# # All BUSTEDS ER Sites: ['1', '10', '14', '23', '24', '25', '29', '30', '32', '33', '35', '39', '40', '41', '49', '50', '51', '52', '53', '54', '55', '57', '58', '59', '68', '71', '72', '75', '77', '78', '79', '80', '93'] 33
# # Intersection (where they both agree): {'54', '40', '1', '33', '25', '80', '59', '29', '93', '78', '52', '32', '51', '53', '23', '14', '58', '72', '57', '77', '50'} 21
# ['11'] 1
# ['10', '24', '30', '35', '39', '41', '49', '55', '68', '71', '75', '79'] 12
#
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/lysozyme.nex.BUSTEDS-MH.json
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/lysozyme.nex.BUSTEDS.json
# # Data loaded
# # Calculating 'Unconstrained model' AICc delta, (BUSTEDS-MH) 2151.862413074277 and (BUSTEDS) 2145.577703032143
# # All BUSTEDS-MH ER Sites: [] 0
# # All BUSTEDS ER Sites: [] 0
# # Intersection (where they both agree): set() 0
# [] 0
# [] 0
#
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/HIV_RT.nex.BUSTEDS-MH.json
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/HIV_RT.nex.BUSTEDS.json
# # Data loaded
# # Calculating 'Unconstrained model' AICc delta, (BUSTEDS-MH) 52050.84852161718 and (BUSTEDS) 52048.51841358669
# # ER Constrained: 335
# # ER Constrained: 335
# # All BUSTEDS-MH ER Sites: ['48', '64', '69', '75', '122', '151', '162', '181', '188', '215', '228', '245'] 12
# # All BUSTEDS ER Sites: ['36', '39', '48', '64', '65', '69', '72', '75', '103', '104', '122', '138', '151', '162', '163', '181', '188', '207', '215', '219', '228', '245'] 22
# # Intersection (where they both agree): {'188', '122', '181', '228', '162', '64', '48', '245', '151', '69', '75', '215'} 12
# [] 0
# ['36', '39', '65', '72', '103', '104', '138', '163', '207', '219'] 10
#
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/HepatitisD.nex.BUSTEDS-MH.json
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/HepatitisD.nex.BUSTEDS.json
# # Data loaded
# # Calculating 'Unconstrained model' AICc delta, (BUSTEDS-MH) 10418.26345775442 and (BUSTEDS) 10424.22529578519
# # ER Constrained: 196
# # ER Constrained: 196
# # All BUSTEDS-MH ER Sites: ['13', '24', '90', '117', '122', '140', '183'] 7
# # All BUSTEDS ER Sites: ['6', '9', '13', '17', '24', '28', '31', '35', '38', '75', '85', '90', '117', '122', '140', '142', '145', '150', '159', '160', '173', '181', '183'] 23
# # Intersection (where they both agree): {'117', '122', '90', '13', '24', '140', '183'} 7
# [] 0
# ['6', '9', '17', '28', '31', '35', '38', '75', '85', '142', '145', '150', '159', '160', '173', '181'] 16
#
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/bglobin.nex.BUSTEDS-MH.json
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/bglobin.nex.BUSTEDS.json
# # Data loaded
# # Calculating 'Unconstrained model' AICc delta, (BUSTEDS-MH) 7384.667181616638 and (BUSTEDS) 7415.590435899347
# # ER Constrained: 144
# # ER Constrained: 144
# # All BUSTEDS-MH ER Sites: ['3', '8', '10', '11', '21', '42', '48', '50', '54', '74', '110', '114', '116', '124', '133'] 15
# # All BUSTEDS ER Sites: ['3', '8', '10', '11', '14', '21', '27', '42', '48', '49', '50', '54', '74', '81', '110', '114', '116', '124', '128', '133'] 20
# # Intersection (where they both agree): {'42', '116', '11', '114', '74', '21', '48', '3', '110', '10', '133', '124', '54', '50', '8'} 15
# [] 0
# ['14', '27', '49', '81', '128'] 5
#
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/yokoyama.rh1.cds.mod.1-990.nex.BUSTEDS-MH.json
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/yokoyama.rh1.cds.mod.1-990.nex.BUSTEDS.json
# # Data loaded
# # Calculating 'Unconstrained model' AICc delta, (BUSTEDS-MH) 25895.9487969114 and (BUSTEDS) 25924.30518545799
# # ER Constrained: 330
# # ER Constrained: 330
# # All BUSTEDS-MH ER Sites: ['14', '277'] 2
# # All BUSTEDS ER Sites: ['13', '14', '16', '19', '35', '36', '42', '46', '93', '96', '107', '108', '122', '144', '149', '160', '163', '195', '196', '213', '214', '236', '260', '271', '273', '277', '281', '282', '297'] 29
# # Intersection (where they both agree): {'277', '14'} 2
# [] 0
# ['13', '16', '19', '35', '36', '42', '46', '93', '96', '107', '108', '122', '144', '149', '160', '163', '195', '196', '213', '214', '236', '260', '271', '273', '281', '282', '297'] 27
#
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS-MH/lysin.nex.BUSTEDS-MH.json
# # Reading: /Users/user/Documents/BUSTEDS-MH/analysis/13-datasets/BUSTEDS/lysin.nex.BUSTEDS.json
# # Data loaded
# # Calculating 'Unconstrained model' AICc delta, (BUSTEDS-MH) 8767.431031855995 and (BUSTEDS) 8765.45910068457
# # ER Constrained: 134
# # ER Constrained: 134
# # All BUSTEDS-MH ER Sites: ['3', '4', '6', '7', '10', '12', '14', '15', '16', '27', '30', '36', '37', '41', '44', '45', '63', '64', '67', '68', '70', '82', '83', '87', '106', '107', '113', '116', '119', '123', '126', '127', '130', '132'] 34
# # All BUSTEDS ER Sites: ['3', '4', '6', '7', '10', '12', '14', '15', '16', '27', '30', '32', '36', '37', '41', '44', '45', '63', '64', '66', '67', '68', '70', '74', '75', '82', '83', '87', '106', '107', '108', '109', '113', '114', '115', '116', '119', '123', '125', '126', '127', '130', '132'] 43
# # Intersection (where they both agree): {'107', '4', '68', '127', '7', '119', '12', '116', '113', '130', '36', '3', '15', '41', '63', '64', '27', '67', '30', '45', '123', '10', '16', '44', '82', '106', '126', '132', '83', '87', '6', '37', '14', '70'} 34
# [] 0
# ['32', '66', '74', '75', '108', '109', '114', '115', '125'] 9

# %% [markdown]
# ## Convert to dataframe

# %%
df = pd.DataFrame.from_dict(df_dict, orient="index")
df = df.reset_index()
df.index += 1
df.rename(columns={'index': 'Gene'}, inplace = True)
df
# Out:
#                           Gene  Sequences  Codons  PValue_BUSTEDS-MH  \
# 1                   InfluenzaA        349     329           0.500000
# 2                         COXI         21     510           0.500000
# 3                      flavNS5         18     342           0.500000
# 4                       ENCenv         23     500           0.500000
# 5                          adh         23     254           0.019474
# 6                       HIVvif         29     192           0.500000
# 7                      camelid        212      96           0.005554
# 8                     lysozyme         19     130           0.500000
# 9                       HIV_RT        476     335           0.001198
# 10                  HepatitisD         33     196           0.032277
# 11                     bglobin         17     144           0.002195
# 12  yokoyama.rh1.cds.mod.1-990         38     330           0.089758
# 13                       lysin         25     134           0.000001
#
#     CV(omega)_BUSTEDS-MH  CV(alpha)_BUSTEDS-MH  omega_3_BUSTEDS-MH  \
# 1               0.433551              0.870295            1.002331
# 2               1.402459              1.316585            1.000000
# 3               1.347522              1.216725            1.075472
# 4               1.204253              0.895045            1.001563
# 5               1.371220              0.535276            3.932678
# 6               0.474882              0.827973            1.804586
# 7               1.036795              0.822342            6.125249
# 8               0.851053              0.964125            1.000000
# 9               1.407424              0.836829           47.059883
# 10              1.302968              0.974883           12.047043
# 11              1.357236              1.133289            9.833868
# 12              1.362607              1.023490            5.518101
# 13              1.300578              0.873833           17.391589
#
#     proportion_3_BUSTEDS-MH   DH_Rate   TH_Rate  TH_Rate_SI  PValue_BUSTEDS  \
# 1                  0.000000  0.062816  0.014894    0.000000    1.047128e-01
# 2                  0.011291  0.000000  0.000000    4.350649    5.000000e-01
# 3                  0.000000  0.364627  0.902814    2.386362    4.822039e-01
# 4                  0.000000  0.012858  0.000000    0.000000    5.000000e-01
# 5                  0.024832  0.000000  0.033881    3.375762    1.639209e-03
# 6                  0.000000  0.003737  0.163413    0.000000    2.270883e-02
# 7                  0.044567  0.162711  0.000000    0.000000    0.000000e+00
# 8                  0.035441  0.000000  0.000000    0.000000    5.000000e-01
# 9                  0.000688  0.039494  0.000000    0.000000    7.174705e-11
# 10                 0.015463  0.144653  0.000000    0.000000    1.118888e-08
# 11                 0.030157  0.000000  0.000000  260.314688    1.182876e-05
# 12                 0.006365  0.243119  0.280597   11.359972    1.099776e-06
# 13                 0.075910  0.000000  0.000000    0.000000    0.000000e+00
#
#     CV(omega)_BUSTEDS  CV(alpha)_BUSTEDS  omega_3_BUSTEDS  \
# 1            1.414214           0.870295         1.580507
# 2            1.389798           1.316585         1.084193
# 3            1.362664           1.216725         1.165364
# 4            1.154258           0.895045         1.176761
# 5            1.363391           0.535276         4.355042
# 6            1.413321           0.827973      1802.234727
# 7            1.331429           0.822342        24.630822
# 8            0.850795           0.964125         3.747829
# 9            1.407637           0.836829        48.964132
# 10           1.332831           0.974883        16.587812
# 11           1.350053           1.133289         8.763965
# 12           1.371595           1.023490         7.037441
# 13           1.232795           0.873833        15.833466
#
#     proportion_3_BUSTEDS  delta_cAIC  ++  +-  -+
# 1               0.289351  -12.388686   0   0  31
# 2               0.009435    6.813631   0   0   0
# 3               0.019089  -41.953286   0   0   0
# 4               0.000000    6.031367   0   0   0
# 5               0.023882    5.309636  15   0   3
# 6               0.000480   -0.640757   0   0   1
# 7               0.020229  -26.241272  21   1  12
# 8               0.000000    6.284710   0   0   0
# 9               0.001009    2.330108  12   0  10
# 10              0.019107   -5.961838   7   0  16
# 11              0.037515  -30.923254  15   0   5
# 12              0.011822  -28.356389   2   0  27
# 13              0.091965    1.971931  34   0   9

# %%
# Save dataframe

# saving the dataframe
df.to_csv('Analysis_13Datasets.csv')

# %%
# Figure legend

"""

Results from the reanalysis of the data sets used in Kosakovsky Pond and Muse (2005), 
Yokoyama et al. (2008), and Chen and Sun (2011), 
arranged by sequence count. 

We ran selection tests with three nonsynonymous and three synonymous rate categories (for BUSTED[S]). 
Column headings are as follows: S, number of sequences; N, number of codons; CV(ω)⁠, 
the coefficient of variation (CV) for the inferred distribution of ω ratios; ω3, 
the maximum likelihood estimate (MLE) of the strength of selection; p3,
the MLE of the proportion of sites under selection (proportion of sites in the ω3 category); 
CV(α)⁠, the CV for the inferred distribution of synonymous rates; ΔAICc, the difference between AICc values of BUSTED and BUSTED[S]. 
The α distribution columns list the estimated values of the 3 α categories along with their estimated frequencies. 
The Sites columns count the number of alignments where at least one method called a site selected (using evidence ratio of at least 5): 
++ both methods yes; +− BUSTED yes, BUSTED[S] no; −+ BUSTED no, BUSTED[S] yes.

"""
# Out:
# '\n\nResults from the reanalysis of the data sets used in Kosakovsky Pond and Muse (2005), \nYokoyama et al. (2008), and Chen and Sun (2011), \narranged by sequence count. \n\nWe ran selection tests with three nonsynonymous and three synonymous rate categories (for BUSTED[S]). \nColumn headings are as follows: S, number of sequences; N, number of codons; CV(ω)\u2060, \nthe coefficient of variation (CV) for the inferred distribution of ω ratios; ω3, \nthe maximum likelihood estimate (MLE) of the strength of selection; p3,\nthe MLE of the proportion of sites under selection (proportion of sites in the ω3 category); \nCV(α)\u2060, the CV for the inferred distribution of synonymous rates; ΔAICc, the difference between AICc values of BUSTED and BUSTED[S]. \nThe α distribution columns list the estimated values of the 3 α categories along with their estimated frequencies. \nThe Sites columns count the number of alignments where at least one method called a site selected (using evidence ratio of at least 5): \n++ both methods yes; +− BUSTED yes, BUSTED[S] no; −+ BUSTED no, BUSTED[S] yes.\n\n'

# %%
# Note Negative delta LL are convergence problems

# %%
# Lower AIC values indicate a better-fit model, and a model with a delta-AIC (the difference between the two AIC values being compared) of more than -2 is considered significantly better than the model it is being compared to

# %%
# Earth Mover's (Kantorovich) distance between two distrbuitions if you want a single number

# %% [markdown]
# ## Visualize table

# %%
df = df.sort_values(by="Gene", ascending=False)
df = df.reset_index(drop=True)
df.index += 1
styled_table = df.style.background_gradient()
styled_table
# Out:
# <style type="text/css">
# #T_2df65_row0_col1, #T_2df65_row0_col10, #T_2df65_row9_col11 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_2df65_row0_col2, #T_2df65_row7_col2, #T_2df65_row8_col5, #T_2df65_row8_col13 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_2df65_row0_col3, #T_2df65_row10_col19 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_2df65_row0_col4, #T_2df65_row12_col12 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_2df65_row0_col5, #T_2df65_row0_col13 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_2df65_row0_col6, #T_2df65_row5_col19 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_2df65_row0_col7, #T_2df65_row1_col2, #T_2df65_row6_col15 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_2df65_row0_col8 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_2df65_row0_col9 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_2df65_row0_col11, #T_2df65_row0_col14, #T_2df65_row1_col6, #T_2df65_row1_col8, #T_2df65_row1_col9, #T_2df65_row1_col10, #T_2df65_row1_col12, #T_2df65_row1_col14, #T_2df65_row1_col15, #T_2df65_row1_col17, #T_2df65_row1_col18, #T_2df65_row1_col19, #T_2df65_row2_col3, #T_2df65_row2_col8, #T_2df65_row2_col9, #T_2df65_row2_col10, #T_2df65_row2_col11, #T_2df65_row2_col18, #T_2df65_row3_col1, #T_2df65_row3_col6, #T_2df65_row3_col7, #T_2df65_row3_col14, #T_2df65_row3_col16, #T_2df65_row3_col17, #T_2df65_row3_col18, #T_2df65_row3_col19, #T_2df65_row4_col2, #T_2df65_row4_col9, #T_2df65_row4_col10, #T_2df65_row4_col11, #T_2df65_row4_col18, #T_2df65_row5_col1, #T_2df65_row5_col8, #T_2df65_row5_col9, #T_2df65_row5_col11, #T_2df65_row5_col18, #T_2df65_row6_col5, #T_2df65_row6_col8, #T_2df65_row6_col11, #T_2df65_row6_col13, #T_2df65_row6_col14, #T_2df65_row6_col18, #T_2df65_row7_col4, #T_2df65_row7_col6, #T_2df65_row7_col7, #T_2df65_row7_col10, #T_2df65_row7_col14, #T_2df65_row7_col17, #T_2df65_row7_col18, #T_2df65_row8_col9, #T_2df65_row8_col10, #T_2df65_row8_col11, #T_2df65_row8_col18, #T_2df65_row9_col7, #T_2df65_row9_col10, #T_2df65_row9_col15, #T_2df65_row9_col17, #T_2df65_row9_col18, #T_2df65_row10_col3, #T_2df65_row10_col9, #T_2df65_row10_col10, #T_2df65_row10_col11, #T_2df65_row10_col15, #T_2df65_row10_col18, #T_2df65_row11_col6, #T_2df65_row11_col7, #T_2df65_row11_col9, #T_2df65_row11_col10, #T_2df65_row11_col14, #T_2df65_row11_col15, #T_2df65_row11_col17, #T_2df65_row11_col18, #T_2df65_row11_col19, #T_2df65_row12_col6, #T_2df65_row12_col8, #T_2df65_row12_col9, #T_2df65_row12_col14, #T_2df65_row12_col17, #T_2df65_row12_col18, #T_2df65_row12_col19 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_2df65_row0_col12, #T_2df65_row0_col19 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_2df65_row0_col15, #T_2df65_row9_col4 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_2df65_row0_col16 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_2df65_row0_col17, #T_2df65_row5_col2 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_2df65_row0_col18, #T_2df65_row1_col3, #T_2df65_row1_col11, #T_2df65_row2_col7, #T_2df65_row2_col17, #T_2df65_row3_col3, #T_2df65_row3_col8, #T_2df65_row3_col9, #T_2df65_row5_col10, #T_2df65_row7_col3, #T_2df65_row7_col12, #T_2df65_row7_col15, #T_2df65_row7_col19, #T_2df65_row9_col3, #T_2df65_row9_col12, #T_2df65_row9_col14, #T_2df65_row10_col1, #T_2df65_row10_col4, #T_2df65_row10_col6, #T_2df65_row11_col3, #T_2df65_row11_col11, #T_2df65_row12_col2, #T_2df65_row12_col3, #T_2df65_row12_col5, #T_2df65_row12_col11, #T_2df65_row12_col13, #T_2df65_row12_col16 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2df65_row1_col1, #T_2df65_row5_col3, #T_2df65_row5_col14 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_2df65_row1_col4, #T_2df65_row7_col5, #T_2df65_row7_col13 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_2df65_row1_col5, #T_2df65_row1_col13 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_2df65_row1_col7 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_2df65_row1_col16, #T_2df65_row10_col12 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_2df65_row2_col1, #T_2df65_row4_col14, #T_2df65_row6_col1, #T_2df65_row6_col10, #T_2df65_row7_col9, #T_2df65_row9_col6, #T_2df65_row11_col1, #T_2df65_row12_col10 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_2df65_row2_col2 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_2df65_row2_col4 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_2df65_row2_col5, #T_2df65_row2_col13 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_2df65_row2_col6 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_2df65_row2_col12 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_2df65_row2_col14, #T_2df65_row3_col10, #T_2df65_row4_col3, #T_2df65_row8_col14, #T_2df65_row9_col8, #T_2df65_row10_col7, #T_2df65_row12_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_2df65_row2_col15 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_2df65_row2_col16 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_2df65_row2_col19 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_2df65_row3_col2 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_2df65_row3_col4 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_2df65_row3_col5, #T_2df65_row3_col13 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_2df65_row3_col11, #T_2df65_row6_col4 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_2df65_row3_col12, #T_2df65_row6_col12, #T_2df65_row10_col16 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_2df65_row3_col15, #T_2df65_row6_col6, #T_2df65_row8_col3, #T_2df65_row8_col15 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_2df65_row4_col1 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_2df65_row4_col4 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_2df65_row4_col5, #T_2df65_row4_col13 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_2df65_row4_col6 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_2df65_row4_col7 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_2df65_row4_col8 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_2df65_row4_col12 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_2df65_row4_col15 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_2df65_row4_col16 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_2df65_row4_col17 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_2df65_row4_col19 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_2df65_row5_col4 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_2df65_row5_col5, #T_2df65_row5_col13 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_2df65_row5_col6 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_2df65_row5_col7, #T_2df65_row8_col8 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_2df65_row5_col12 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_2df65_row5_col15 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_2df65_row5_col16 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_2df65_row5_col17 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_2df65_row6_col2 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_2df65_row6_col3, #T_2df65_row6_col9, #T_2df65_row11_col8 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_2df65_row6_col7 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_2df65_row6_col16 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_2df65_row6_col17 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_2df65_row6_col19, #T_2df65_row9_col19 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_2df65_row7_col1 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_2df65_row7_col8 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_2df65_row7_col11 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_2df65_row7_col16 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_2df65_row8_col1, #T_2df65_row12_col15 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_2df65_row8_col2, #T_2df65_row8_col6 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_2df65_row8_col4 {
#   background-color: #045

# %%
import seaborn as sns


sns.catplot(y = "Gene",       # x variable name
            x = "omega_3_BUSTEDS",       # y variable name
            data = df,     # dataframe to plot
            kind = "bar")

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
#sns.set(rc={'figure.figsize':(11.7,8.27)})

import matplotlib.pyplot as plt
#plt.ylim(10, 40)
#ax.set(ylim=(10, 40))
from matplotlib import rcParams

# figure size in inches
#rcParams['figure.figsize'] = 120, 8

#penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=df, kind="bar",
    y="Gene", x="omega_3_BUSTEDS-MH",
    ci="sd", palette="dark", alpha=.9, height=8
)

g.despine(left=True)
g.set_axis_labels("Omega3 Value", "Gene")
#g.legend.set_title("")

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
#sns.set(rc={'figure.figsize':(11.7,8.27)})

import matplotlib.pyplot as plt
#plt.ylim(10, 40)
#ax.set(ylim=(10, 40))
from matplotlib import rcParams

# figure size in inches
#rcParams['figure.figsize'] = 120, 8

#penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=df, kind="bar",
    y="Gene", x="omega_3_BUSTEDS-MH",
    ci="sd", palette="dark", alpha=.9, height=8
)

g.despine(left=True)
g.set_axis_labels("Omega3 Value", "Gene")
#g.legend.set_title("")

# %%
import seaborn as sns
import numpy as np

sns.catplot(y = "Gene",       # x variable name
            x = "omega_3_BUSTEDS-MH",       # y variable name
            data = df,     # dataframe to plot
            kind = "bar")

# %%
import matplotlib.pyplot as plt
import pandas as pd
from pandas.table.plotting import table # EDIT: see deprecation warnings below

ax = plt.subplot(111, frame_on=False) # no visible frame
ax.xaxis.set_visible(False)  # hide the x axis
ax.yaxis.set_visible(False)  # hide the y axis

table(ax, df)  # where df is your data frame

#plt.savefig('mytable.png')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/bl/7cq20h0x42sd3fsm70jl08j80000gn/T/ipykernel_23473/187975736.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 import pandas as pd
# ----> 3 from pandas.table.plotting import table # EDIT: see deprecation warnings below
#       4
#       5 ax = plt.subplot(111, frame_on=False) # no visible frame
#
# ModuleNotFoundError: No module named 'pandas.table'

# %%
import plotly.figure_factory as ff
import pandas as pd

fig =  ff.create_table(df)

fig.update_layout(
    autosize=False,
    width=3200,
    height=800,
)

#fig.write_image("table_plotly.png", scale=2)
fig.show()

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=penguins, kind="bar",
    x="species", y="body_mass_g", hue="sex",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Body mass (g)")
g.legend.set_title("")

# %%
penguins

# %%
df.T

# %%
df.plot()
