# %% [markdown]
# ## Imports

# %%
# Imports
import pandas as pd
import plotly.express as px
from prettytable import PrettyTable
import plotly.graph_objects as go
import numpy as np
import random
import csv
import os
import json
import altair as alt
from tqdm import tqdm
import numpy as np
import seaborn as sns
#import dataframe_image as dfi
from numpy.random import seed
from numpy.random import randn
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot
alt.data_transformers.disable_max_rows()

# %% [markdown]
# ## Declares

# %%
WD = os.path.join("E:\\", "BUSTEDS-MH")
#WD = "/Users/alex/Documents/BUSTEDS-MH"
DATA = os.path.join(WD, "tables", "Table_EMPIRICAL_UNMASKED_SELECTOME_BUSTEDS_and_BUSTEDS-MH.csv")

# %%
pct = lambda a, b: (a / b) * 100
pct_formatted = lambda a, b: str(round((a / b) * 100, 2)) + "%"

# %%
print("Reading:", DATA)
df = pd.read_csv(DATA)
df = df.reset_index(drop=True)
df.index += 1
df

# %%
df.columns

# %% [markdown]
# ## Plots

# %%
source = df
#source = source[source["SRV3"] < 100.0] # Gate

alt.Chart(source).mark_bar(
    opacity=0.6,
    binSpacing=0
).encode(
    alt.X('ΔcAIC', bin=alt.Bin(maxbins=100)),
    alt.Y('count()', stack=None),
    alt.Color('Method')
)

# %%
source = df


alt.Chart(source).mark_bar(
    opacity=0.6,
    binSpacing=0
).encode(
    alt.X('LRT p-value', bin=alt.Bin(maxbins=100)),
    alt.Y('count()', stack=None),
    alt.Color('Method')
)

# %%
source = df
#source = source[source["SRV3"] < 100.0] # Gate

alt.Chart(source).mark_bar(
    opacity=0.6,
    binSpacing=0
).encode(
    alt.X('CV(alpha)', bin=alt.Bin(maxbins=100)),
    alt.Y('count()', stack=None),
    alt.Color('Method')
)

# %%
source = df
#source = source[source["SRV3"] < 100.0] # Gate

chart1 = alt.Chart(source).mark_point(
    opacity=0.6,
    binSpacing=0
).encode(
    alt.X('DH_Rate', bin=alt.Bin(maxbins=50)),
    alt.Y('count()', stack=None),
    alt.Color('Method')
).properties(
    width=200, 
    height=400)

chart2 = alt.Chart(source).mark_point(
    opacity=0.6,
    binSpacing=0
).encode(
    alt.X('TH_Rate', bin=alt.Bin(maxbins=50)),
    alt.Y('count()', stack=None),
    alt.Color('Method')
).properties(
    width=200, 
    height=400)

chart3 = alt.Chart(source).mark_point(
    opacity=0.6,
    binSpacing=0
).encode(
    alt.X('TH_Rate_SI', bin=alt.Bin(maxbins=50)),
    alt.Y('count()', stack=None),
    alt.Color('Method')
).properties(
    width=200, 
    height=400)


chart1 | chart2 | chart3

# %%
df["DH_Rate"].describe()

# %%
source = df
chartDH = alt.Chart(source).mark_circle(color = "steelblue").encode(
    x    = alt.X("Sequences"),
    y    = alt.Y("DH_Rate"),
    color='binned_rate:O'
).properties(
    width=200, 
    height=400).transform_bin(
    'binned_rate', 'Sequences', bin=alt.Bin(maxbins=5)
)

chartTH = alt.Chart(source).mark_circle(color = "steelblue").encode(
    x    = alt.X("Sequences"),
    y    = alt.Y("TH_Rate"),
    color='binned_rate:O'
).properties(
    width=200, 
    height=400).transform_bin(
    'binned_rate', 'Sequences', bin=alt.Bin(maxbins=5)
)

chartTHSI = alt.Chart(source).mark_circle(color = "steelblue").encode(
    x    = alt.X("Sequences"),
    y    = alt.Y("TH_Rate_SI"),
    color='binned_rate:O'
).properties(
    width=200, 
    height=400).transform_bin(
    'binned_rate', 'Sequences', bin=alt.Bin(maxbins=5)
)


chartDH | chartTH | chartTHSI

# %%
# MH rates by w3 parameter for BUSTEDS-MH
source = df
source = source[source["Method"] == "BUSTEDS-MH"] # By method

DH_Gate = 10
TH_Gate = 100
THSI_Gate = 10000

w3_Gate = 10000

chartDH = alt.Chart(source).mark_circle(color = "steelblue").encode(
    x    = alt.X("w3", scale=alt.Scale(domain=[0, w3_Gate], clamp=True)),
    y    = alt.Y("DH_Rate",  scale=alt.Scale(domain=[0, DH_Gate], clamp=True))
).properties(
    width=200, 
    height=400).transform_bin(
    'binned_rate', 'w3', bin=alt.Bin(maxbins=15)
)

chartTH = alt.Chart(source).mark_circle(color = "steelblue").encode(
    x    = alt.X("w3",  scale=alt.Scale(domain=[0, w3_Gate], clamp=True)),
    y    = alt.Y("TH_Rate",  scale=alt.Scale(domain=[0, TH_Gate], clamp=True))
).properties(
    width=200, 
    height=400).transform_bin(
    'binned_rate', 'w3', bin=alt.Bin(maxbins=15)
)

chartTHSI = alt.Chart(source).mark_circle(color = "steelblue").encode(
    x    = alt.X("w3", scale=alt.Scale(domain=[0, w3_Gate], clamp=True)),
    y    = alt.Y("TH_Rate_SI",  scale=alt.Scale(domain=[0, THSI_Gate], clamp=True))
).properties(
    width=200, 
    height=400).transform_bin(
    'binned_rate', 'w3', bin=alt.Bin(maxbins=15)
)


chartDH | chartTH | chartTHSI

# %%
source = df
chartDH = alt.Chart(source).mark_circle(color = "steelblue").encode(
    x    = alt.X("Sequences"),
    y    = alt.Y("DH_Rate"),
    color='binned_rate:O'
).properties(
    width=200, 
    height=400).transform_bin(
    'binned_rate', 'Sequences', bin=alt.Bin(maxbins=5)
)

chartTH = alt.Chart(source).mark_circle(color = "steelblue").encode(
    x    = alt.X("Sequences"),
    y    = alt.Y("TH_Rate"),
    color='binned_rate:O'
).properties(
    width=200, 
    height=400).transform_bin(
    'binned_rate', 'Sequences', bin=alt.Bin(maxbins=5)
)

chartTHSI = alt.Chart(source).mark_circle(color = "steelblue").encode(
    x    = alt.X("Sequences"),
    y    = alt.Y("TH_Rate_SI"),
    color='binned_rate:O'
).properties(
    width=200, 
    height=400).transform_bin(
    'binned_rate', 'Sequences', bin=alt.Bin(maxbins=5)
)


chartDH | chartTH | chartTHSI

# %%
source = df

chartDH = alt.Chart(source).mark_circle(color = "steelblue").encode(
    x    = alt.X("Codons"),
    y    = alt.Y("DH_Rate"),
    color='binned_rate:O'
).properties(
    width=200, 
    height=400).transform_bin(
    'binned_rate', 'Codons', bin=alt.Bin(maxbins=5)
)

chartTH = alt.Chart(source).mark_circle(color = "steelblue").encode(
    x    = alt.X("Codons"),
    y    = alt.Y("TH_Rate"),
    color='binned_rate:O'
).properties(
    width=200, 
    height=400).transform_bin(
    'binned_rate', 'Codons', bin=alt.Bin(maxbins=5)
)

chartTHSI = alt.Chart(source).mark_circle(color = "steelblue").encode(
    x    = alt.X("Codons"),
    y    = alt.Y("TH_Rate_SI"),
    color='binned_rate:O'
).properties(
    width=200, 
    height=400).transform_bin(
    'binned_rate', 'Codons', bin=alt.Bin(maxbins=5)
)


chartDH | chartTH | chartTHSI

# %%
source = df

chart1 = alt.Chart(source).mark_circle(color = "steelblue").encode(
    x    = alt.X("w1", bin=alt.Bin(maxbins=30)),
    y    = alt.Y("count()"),
    color='Method'
).properties(
    width=200, 
    height=400).transform_bin(
    'binned_rate', 'w1', bin=alt.Bin(maxbins=5)
)

chart2 = alt.Chart(source).mark_circle(color = "steelblue").encode(
    x    = alt.X("w2", bin=alt.Bin(maxbins=30)),
    y    = alt.Y("count()"),
    color='Method'
).properties(
    width=200, 
    height=400).transform_bin(
    'binned_rate', 'w2', bin=alt.Bin(maxbins=5)
)

chart3 = alt.Chart(source).mark_circle(color = "steelblue").encode(
    x    = alt.X("w3", bin=alt.Bin(maxbins=30)),
    y    = alt.Y("count()"),
    color='Method'
).properties(
    width=200, 
    height=400).transform_bin(
    'binned_rate', 'w3', bin=alt.Bin(maxbins=5)
)


#chartDH | chartTH | chartTHSI
chart1 | chart2 | chart3

# %%
def process(df, method, parameter, tag, gate=100, bins=15, min_members=100):
    source = df
    source = source[source["Method"] == method] # By method
    source = source[source[parameter] < gate] # Gate
    bins = np.linspace(0, gate, bins)
    count = 1
    labels = []
    for x in range(len(bins) - 1):
        labels.append(count)
        count+=1
    #end for
    source['binned'] = pd.cut(source[parameter], bins=bins, labels=labels)
    #source['binned'] = pd.qcut(source[parameter], q=bins, labels=labels)
    df_holder = []
    for item in labels:
        # Process each label
        # Get average w3, fraction under selection
        df_h = source[source['binned'] == item]
        df_h["num_bin_items"] = int(df_h.shape[0])
        df_h[tag] = float(df_h[parameter].mean())
        if df_h.shape[0] > 0:
            df_h["fraction_under_selection"] = (df_h[df_h["LRT p-value"] <= 0.05].shape[0] / df_h.shape[0]) 
        # add assert, that the bin has more than X members
        df_holder.append(df_h)
    #end for
    return pd.concat(df_holder)
#end method

# Omegas
#df1 = process(df, "BUSTEDS-MH", "w3", "average_w3", bins=15)
#df2 = process(df, "BUSTEDS","w3", "average_w3", bins=15)

# SRVs
#df1_SRV = process(df, "BUSTEDS-MH", "CV(alpha)", "average_CV(alpha)", gate=2, bins=15)
#df2_SRV = process(df, "BUSTEDS", "CV(alpha)", "average_CV(alpha)", gate=2, bins=15)

# DH_Rate
#df1_DH_Rate = process(df, "BUSTEDS-MH", "DH_Rate", "average(DH_Rate)", gate=2, bins=15)

# TH Rate
#df1_TH_Rate = process(df, "BUSTEDS-MH", "TH_Rate", "average(TH_Rate)", gate=2, bins=15)

# TH_SI Rate
#df1_TH_Rate_SI = process(df, "BUSTEDS-MH", "TH_Rate_SI", "average(TH_Rate_SI)", gate=2, bins=15)

df1c = process(df, "BUSTEDS-MH", "Codons", "average_Codons", bins=15)
df2c = process(df, "BUSTEDS","Codons", "average_Codons", bins=15)


df1 = process(df, "BUSTEDS-MH", "Sequences", "average_Sequences", bins=15)
df2 = process(df, "BUSTEDS","Sequences", "average_Sequences", bins=15)

# %%
source = df1c

line1c = alt.Chart(source).mark_circle().encode(
    x = alt.X('average_Codons'),
    y='fraction_under_selection',
    size="num_bin_items"
).properties(width=400, height=300)

source=df2c # BUSTEDS
line2c = alt.Chart(source).mark_circle(color="red").encode(
    x = alt.X('average_Codons'),
    y='fraction_under_selection',
    size="num_bin_items",
).properties(width=400, height=300)



source = df1

line1 = alt.Chart(source).mark_circle().encode(
    x = alt.X('average_Sequences'),
    y='fraction_under_selection',
    size="num_bin_items"
).properties(width=400, height=300)

source=df2 # BUSTEDS
line2 = alt.Chart(source).mark_circle(color="red").encode(
    x = alt.X('average_Sequences'),
    y='fraction_under_selection',
    size="num_bin_items",
).properties(width=400, height=300)



line1c + line1c.transform_loess('average_Codons', 'fraction_under_selection').mark_line(size=6) + line2c + line2c.transform_loess('average_Codons', 'fraction_under_selection').mark_line(color="red") | line1 + line1.transform_loess('average_Sequences', 'fraction_under_selection').mark_line(size=6) + line2 + line2.transform_loess('average_Sequences', 'fraction_under_selection').mark_line(color="red")


#line1 + line1.transform_loess('average_Sequences', 'fraction_under_selection').mark_line(size=6) + line2 + line2.transform_loess('average_Sequences', 'fraction_under_selection').mark_line(color="red")
